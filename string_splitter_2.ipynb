# %%
import pandas as pd

df = pd.read_excel("Списки поступающих бакалавриат.xlsx")
df.to_excel("test_file.xlsx")
df.head(20)
# Out:
#                                                            Unnamed: 1  \
# 0                                                 NaN             NaN
# 1   Дата формирования - 08.07.2026. Время формиров...             NaN
# 2                                                                 NaN
# 3   Конкурсная группа - Адаптивный спорт (ЗБ осправо)             NaN
# 4            Основание поступления - Бюджетная Основа             NaN
# 5                                                                 NaN
# 6                                                 NaN             NaN
# 7                                                   №  Уникальный код
# 8                                                   1         1085888
# 9                                                   2          982250
# 10                                                  3         1203988
# 11                                                  4          970473
# ...
